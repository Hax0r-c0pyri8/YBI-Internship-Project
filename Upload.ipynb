# %%
# !apt install gh -y
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   gh
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 6,242 kB of archives.
# After this operation, 33.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gh amd64 2.4.0+dfsg1-2 [6,242 kB]
# Fetched 6,242 kB in 1s (6,544 kB/s)
# sh: 0: getcwd() failed: No such file or directory
# Selecting previously unselected package gh.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../gh_2.4.0+dfsg1-2_amd64.deb ...
# Unpacking gh (2.4.0+dfsg1-2) ...
# Setting up gh (2.4.0+dfsg1-2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !gh --version
# Out:
# gh version 2.4.0+dfsg1 (2022-03-23 Ubuntu 2.4.0+dfsg1-2)
# https://github.com/cli/cli/releases/latest

# %%
# !gh auth login --with-token <<< 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

# %%
# !gh auth status
# Out:
# github.com
#   ✓ Logged in to github.com as Hax0r-c0pyri8 (/root/.config/gh/hosts.yml)
#   ✓ Git operations for github.com configured to use https protocol.
#   ✓ Token: *******************

# %%
# !gh repo create YBI-Internship-Project --public --confirm
# Out:
# Flag --confirm has been deprecated, Pass any argument to skip confirmation prompt
# ✓ Created repository Hax0r-c0pyri8/YBI-Internship-Project on GitHub

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
# 'Bank Churn Modelling.csv'  'Bank Customer Churn Model.ipynb'   Upload.ipynb

# %%
# !cp -r /content/drive/MyDrive/Colab\ Notebooks/* /content/YBI-Internship-Project/
# Out:
# cp: target '/content/YBI-Internship-Project/' is not a directory

# %%
# !ls /content/
# Out:
# drive  sample_data

# %%
# %cd /content/
# !git clone https://github.com/Hax0r-c0pyri8/YBI-Internship-Project.git
# Out:
# /content
# Cloning into 'YBI-Internship-Project'...
# ...
